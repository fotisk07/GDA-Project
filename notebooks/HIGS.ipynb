# %%
import pandas as pd
from kmtr.datasets_and_metrics import mini_higgs, Higgs
from kmtr.datasets_and_metrics import one_minus_auc

# %%
X_train,y_train, X_test, y_test= Higgs()

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)

# %%
one_minus_auc(y_pred, y_test)
# Out:
# 0.3161771871460326
