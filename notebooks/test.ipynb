# %%
from kmtr.kernel_solvers import FalkonSolverGPU
from kmtr.datasets import MDS
from sklearn.model_selection import train_test_split
import numpy as np

# %%
X_tr, y_tr, X_te, y_te = MDS()

# %%
from sklearn.linear_model import LinearRegression

bougo = LinearRegression()
bougo.fit(X_tr, y_tr)
# Out:
# LinearRegression()

# %%
bougo_thinks = bougo.predict(X_te)

# %%
relative_error(bougo_thinks, y_te)
# Out:
# np.float64(0.08450948831649109)

# %%
plt.scatter(y_te, bougo_thinks)
np.corrcoef(y_te, bougo_thinks)
# Out:
# array([[1.        , 0.48631451],
#        [0.48631451, 1.        ]])

# %%
sns.kdeplot(bougo_thinks)
# Out:
# <Axes: ylabel='Density'>

# %%
y_te.shape
# Out:
# (51535,)

# %%
y_pred = np.load("est.npy")
y_pred
# Out:
# array([ 374.78417206,   93.88314438,  118.29463959, ...,  -94.64395905,
#        -198.1602211 ,  116.45796204], shape=(51535,))

# %%
y_cst = y_tr.mean()

# %%
def relative_error(y_pred, y_true):
    return np.abs((y_pred - y_true) / 80).mean()

# %%
relative_error(y_pred, y_te)
# Out:
# np.float64(22.69814036428038)

# %%
relative_error(y_cst, y_te)
# Out:
# np.float64(0.10145026165802783)

# %%
import seaborn as sns
sns.kdeplot(y_pred)
# Out:
# <Axes: ylabel='Density'>

# %%
idx = np.logical_and(y_pred > 1950,y_pred < 2100)

# %%
import matplotlib.pyplot as plt
plt.scatter(y_te[idx], y_pred[idx])
np.corrcoef(y_pred, y_te)
# Out:
# array([[1.        , 0.03380371],
#        [0.03380371, 1.        ]])

# %%
import seaborn as sns
sns.kdeplot(y_te)
# Out:
# <Axes: ylabel='Density'>

# %%
relative_error(y_pred, y_test)
# Out:
# np.float64(34.63731578025516)
