# %%
import pandas as pd

# %%
data =

# %%
with pd.read_csv("data/HIGGS.csv", chunksize=4) as reader:
    for chunk in reader:
        print(chunk)
        break
# Out:
#    1.000000000000000000e+00  8.692932128906250000e-01  \
# 0                       1.0                  0.907542
# 1                       1.0                  0.798835
# 2                       0.0                  1.344385
# 3                       1.0                  1.105009
#
#    -6.350818276405334473e-01  2.256902605295181274e-01  \
# 0                   0.329147                  0.359412
# 1                   1.470639                 -1.635975
# 2                  -0.876626                  0.935913
# 3                   0.321356                  1.522401
#
#    3.274700641632080078e-01  -6.899932026863098145e-01  \
# 0                  1.497970                  -0.313010
# 1                  0.453773                   0.425629
# 2                  1.992050                   0.882454
# 3                  0.882808                  -1.205349
#
#    7.542022466659545898e-01  -2.485731393098831177e-01  \
# 0                  1.095531                  -0.557525
# ...
